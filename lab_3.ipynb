# %% [markdown]
# *Нагорный Глеб 4 курс группа КМА Лабораторная работа №3 (Челябинск)*

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import odeint
url = 'https://raw.githubusercontent.com/AndreyRyndin3/MMVSULAB1/main/rostov.csv'
df = pd.read_csv(url)
print(df)
Years = np.array(df['Years'])
Population = np.array(df['Population'])
def dydt(Years,Population):
  k = 0.0056
  return k*Years

plt.plot(Years, Population)
plt.grid(True)
# Out:
#     Years  Population
# 0    2003     1062100
# 1    2005     1054800
# 2    2009     1049991
# 3    2010     1048124
# 4    2012     1099560
# 5    2013     1103733
# 6    2014     1109835
# 7    2015     1114806
# 8    2016     1119875
# 9    2017     1125299
# 10   2018     1130305
# 11   2019     1133307
# 12   2020     1137904
# 13   2021     1137704
# 14   2022     1134694
